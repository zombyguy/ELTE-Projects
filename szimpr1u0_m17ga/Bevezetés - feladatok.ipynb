# %% [markdown]
# ## 1. feladat ##

# %%
factorial(1000)
# Out:
# ...

# %% [markdown]
# ## 2. feladat ##

# %%
n(e, digits=1000)
# Out:
# 2....

# %%
n(pi, digits=1000)
# Out:
# 3....

# %% [markdown]
# ## 3. feladat ##

# %%
(3+2*I)*(5-3*I)
# Out:
# I + 21

# %% [markdown]
# ## 4. feladat ##

# %%
x = var('x')

# %%
solve(sin(x)==2, x)
# Out:
# [x == arcsin(2)]

# %% [markdown]
# ## 5. feladat ##

# %%
factor(307511943)
# Out:
# 3 * 102503981

# %% [markdown]
# ## 6. feladat ##

# %%
floor(pi*10**2017) % 10**10 #első megoldás
# Out:
# 789512694

# %%
floor(pi*10**2017) - floor(pi*10**2007)*10**10 #második megoldás
# Out:
# 789512694

# %% [markdown]
# ## 7. feladat ##

# %%
a = var('a')

# %%
cos(7*a).trig_expand()
# Out:
# cos(a)^7 - 21*cos(a)^5*sin(a)^2 + 35*cos(a)^3*sin(a)^4 - 7*cos(a)*sin(a)^6

# %% [markdown]
# ## 8. feladat ##

# %%
a = var('a')
b = var('b')
c = var('c')

# %%
factor(a**3 * b + b**3 * c + c**3 * a - a*b**3 - b*c**3 - c*a**3)
# Out:
# (a + b + c)*(a - b)*(a - c)*(b - c)

# %% [markdown]
# ## 9. feladat ##

# %%
n = var('n')

# %%
s = sum(1/n**4, n, 1, oo)

# %%
print(s)
print(s.n())
# Out:
# 1/90*pi^4
# 1.08232323371114
